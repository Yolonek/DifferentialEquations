# %% [markdown]
# # Separable Equations
# DE is separable, when:
# $$\frac{dy}{dx} = g(x)h(y)$$

# %%
import sys
sys.path.append('..')

# %%
from CommonFunctions import *
import numpy as np
import sympy as sp
from matplotlib import pyplot as plt

# %%
x, y = sp.symbols('x y')
f = sp.Function('f')(x)

# %% [markdown]
# # $\frac{dy}{dx} = \frac{y}{1 + x}$

# %%
diff_eq = sp.Eq(f.diff(x), f / (1 + x))
diff_eq.subs(f, y)
# Out:
# Eq(Derivative(y, x), y/(x + 1))

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), C1*(x + 1))

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# y/(x + 1)

# %%
C1 = sp.Symbol('C1')
a, b = -5, 5
x_values = np.linspace(a, b, 500)
consts = [[(C1, i)] for i in range(-5, 6, 2)]
figure, axes = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes, threshold=(a, b), legend=False)
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes, title=False)

# %% [markdown]
# # $\frac{dy}{dx} = y^2 - 4$

# %%
diff_eq = sp.Eq(f.diff(x), f**2 - 4)
diff_eq.subs(f, y)
# Out:
# Eq(Derivative(y, x), y**2 - 4)

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), 2/tanh(C1 - 2*x))

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# y**2 - 4

# %%
consts = [[(C1, i)] for i in range(-5, 6, 2)]
figure2, axes2 = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
# plot_many_functions(solution, x, diff_eq, x_values, consts, axes2, threshold=(a, b), legend=False)
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes2, title=False)
initial_conditions = np.array([0])
for init_x in range(-4, 5, 1):
    plot_numeric_solutions(direction_field.subs(y, f), x, f, initial_conditions, init_x, (a, b), 100, axes2, legend=False, title=True, threshold=(a, b))

# %% [markdown]
# # $(e^{2y} - y) \cos{x} \frac{dy}{dx} = e^y \sin{2x}$

# %%
diff_eq = sp.Eq((sp.exp(2 * f) - f) * sp.cos(x) * f.diff(x), sp.exp(f) * sp.sin(2 * x))
diff_eq.subs(f, y)
# Out:
# Eq((-y + exp(2*y))*cos(x)*Derivative(y, x), exp(y)*sin(2*x))

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# 2*exp(y)*sin(x)/(-y + exp(2*y))

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq((-f(x) - 1)*exp(-f(x)) - exp(f(x)) - 2*cos(x), C1)

# %%
figure3, axes3 = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
initial_conditions = np.arange(-4, 4, .5)
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes3, title=True)
initial_conditions = np.arange(-4, 4.2, .5)
initial_x = -4
plot_numeric_solutions(direction_field.subs(y, f), x, f, initial_conditions, initial_x, (a, b), 100, axes3, legend=False, title=True, threshold=(a, b))
