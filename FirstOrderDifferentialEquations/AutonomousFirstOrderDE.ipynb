# %%
import sys
sys.path.append('..')

# %%
from CommonFunctions import *
import numpy as np
import sympy as sp
from matplotlib import pyplot as plt

# %% [markdown]
# # $\frac{dy}{dx} = y^2$

# %%
x, y = sp.symbols('x y')
f = sp.Function('f')(x)

# %%
diff_eq = sp.Eq(f.diff(x), f**2)
diff_eq.subs(f, y)
# Out:
# Eq(Derivative(y, x), y**2)

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# y**2

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), -1/(C1 + x))

# %%
C1 = sp.Symbol('C1')
a, b = -5, 5
x_values = np.linspace(a, b, 500)
consts = [[(C1, i)] for i in range(-5, 6, 2)]
figure, axes = plt.subplots(2, 1, figsize=(8, 14), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes[0])
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes[1])
# Out:
# <lambdifygenerated-1>:2: RuntimeWarning: divide by zero encountered in divide
#   return -1/(x - 5)
# <lambdifygenerated-6>:2: RuntimeWarning: divide by zero encountered in divide
#   return -1/(x + 5)

# %% [markdown]
# # $\frac{dy}{dx} = 1 - xy$

# %%
diff_eq = sp.Eq(f.diff(x), 1 - x * f)
diff_eq
# Out:
# Eq(Derivative(f(x), x), -x*f(x) + 1)

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), (C1 + sqrt(2)*sqrt(pi)*erfi(sqrt(2)*x/2)/2)*exp(-x**2/2))

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# -x*y + 1

# %%
a, b = -5, 5
figure2, axes2 = plt.subplots(1, 1, figsize=(8, 10), layout='constrained')

initial_conditions = np.arange(-4, 5, 1)
initial_x = 0
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes2, title=False)
plot_numeric_solutions(direction_field.subs(y, f), x, f, initial_conditions, initial_x, (a, b), 100, axes2, legend=True, title=True, threshold=(a, b))

# %% [markdown]
# # $\frac{dy}{dx} = \sin{x} \cos{y}$

# %%
diff_eq = sp.Eq(f.diff(x), sp.sin(x) * sp.cos(f))
diff_eq
# Out:
# Eq(Derivative(f(x), x), sin(x)*cos(f(x)))

# %%
solution = sp.dsolve(diff_eq, f)
solution[0]
# Out:
# Eq(f(x), pi - asin((C1 + exp(2*cos(x)))/(C1 - exp(2*cos(x)))))

# %%
solution[1]
# Out:
# Eq(f(x), asin((C1 + exp(2*cos(x)))/(C1 - exp(2*cos(x)))))

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# sin(x)*cos(y)

# %%
a, b = -5, 5
x_values = np.linspace(a, b, 500)
consts = [[(C1, -10)], [(C1, -5)], [(C1, -1)]]
figure3, axes3 = plt.subplots(1, 1, figsize=(8, 10), layout='constrained')
plot_many_functions(solution[0], x, diff_eq, x_values, consts, axes3, title=False, legend=False)
plot_many_functions(solution[1], x, diff_eq, x_values, consts, axes3, title=False, legend=False)
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes3, title=False)

initial_conditions = np.arange(-4, 5, 1)
initial_x = 0
plot_numeric_solutions(direction_field.subs(y, f), x, f, initial_conditions, initial_x, (a, b), 100, axes3, legend=True, title=True, threshold=(a, b))

# %% [markdown]
# # $\frac{dy}{dx} = x$

# %%
diff_eq = sp.Eq(f.diff(x), x)
diff_eq
# Out:
# Eq(Derivative(f(x), x), x)

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), C1 + x**2/2)

# %%
direction_field = diff_eq.rhs
direction_field
# Out:
# x

# %%
consts = [[(C1, i)] for i in range(-5, 5, 1)]
figure4, axes4 = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes4, legend=False, threshold=(a, b))
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes4, title=False)

# %% [markdown]
# # $\frac{dy}{dx} = x + y$

# %%
diff_eq = sp.Eq(f.diff(x), x + f)
diff_eq
# Out:
# Eq(Derivative(f(x), x), x + f(x))

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), C1*exp(x) - x - 1)

# %%
direction_field = diff_eq.rhs.subs(f, y)
direction_field
# Out:
# x + y

# %%
consts = [[(C1, i)] for i in range(-100, -19, 20)]
consts += [[(C1, i)] for i in range(-15, 16, 2)]
consts += [[(C1, i)] for i in range(20, 101, 20)]
consts.append([(C1, 0)])
figure5, axes5 = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes5, legend=False, threshold=(a, b))
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes5, title=False)

# %% [markdown]
# # $\frac{dy}{dx} = \frac{1}{y}$

# %%
diff_eq = sp.Eq(f.diff(x), 1 / f)
diff_eq
# Out:
# Eq(Derivative(f(x), x), 1/f(x))

# %%
solution = sp.dsolve(diff_eq, f)
solution[0]
# Out:
# Eq(f(x), -sqrt(C1 + 2*x))

# %%
solution[1]
# Out:
# Eq(f(x), sqrt(C1 + 2*x))

# %%
direction_field = diff_eq.rhs.subs(f, y)
direction_field
# Out:
# 1/y

# %%
consts = [[(C1, i)] for i in range(0, 6, 1)]
figure6, axes6 = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution[0], x, diff_eq, x_values, consts, axes6, legend=False, threshold=(a, b))
plot_many_functions(solution[1], x, diff_eq, x_values, consts, axes6, legend=False, threshold=(a, b))
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes6, title=False)
# Out:
# <lambdifygenerated-89>:2: RuntimeWarning: invalid value encountered in sqrt
#   return -sqrt(2)*sqrt(x)
# <lambdifygenerated-90>:2: RuntimeWarning: invalid value encountered in sqrt
#   return -sqrt(2*x + 1)
# <lambdifygenerated-91>:2: RuntimeWarning: invalid value encountered in sqrt
#   return -sqrt(2*x + 2)
# <lambdifygenerated-92>:2: RuntimeWarning: invalid value encountered in sqrt
#   return -sqrt(2*x + 3)
# <lambdifygenerated-93>:2: RuntimeWarning: invalid value encountered in sqrt
#   return -sqrt(2*x + 4)
# <lambdifygenerated-94>:2: RuntimeWarning: invalid value encountered in sqrt
#   return -sqrt(2*x + 5)
# <lambdifygenerated-95>:2: RuntimeWarning: invalid value encountered in sqrt
#   return sqrt(2)*sqrt(x)
# <lambdifygenerated-96>:2: RuntimeWarning: invalid value encountered in sqrt
#   return sqrt(2*x + 1)
# <lambdifygenerated-97>:2: RuntimeWarning: invalid value encountered in sqrt
#   return sqrt(2*x + 2)
# ...

# %% [markdown]
# # $\frac{dy}{dx} = y - \cos(\frac{1}{2}x)$

# %%
diff_eq = sp.Eq(f.diff(x), f - sp.cos(sp.Rational(1, 2)*x))
diff_eq
# Out:
# Eq(Derivative(f(x), x), f(x) - cos(x/2))

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), C1*exp(x) - 2*sin(x/2)/5 + 4*cos(x/2)/5)

# %%
direction_field = diff_eq.rhs.subs(f, y)
direction_field
# Out:
# y - cos(x/2)

# %%
consts = [[(C1, i)] for i in range(-5, 6, 1)]
consts.append([(C1, -0.3)])
consts.append([(C1, 0.3)])
figure7, axes7 = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes7, threshold=(a, b))
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes7, title=False)

# %% [markdown]
# # $\frac{dy}{dx} = y - y^3$

# %%
diff_eq = sp.Eq(f.diff(x), f - f**3)
diff_eq
# Out:
# Eq(Derivative(f(x), x), -f(x)**3 + f(x))

# %%
solution = sp.dsolve(diff_eq, f)
solution[0]
# Out:
# Eq(f(x), -sqrt(-exp(2*x)/(C1 - exp(2*x))))

# %%
solution[1]
# Out:
# Eq(f(x), sqrt(-exp(2*x)/(C1 - exp(2*x))))

# %%
direction_field = diff_eq.rhs.subs(f, y)
direction_field
# Out:
# -y**3 + y

# %%
figure8, axes8 = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes8, title=True)

initial_conditions = np.array([0.5, -0.5])
initial_x_list = [-3, 0,  3]
for init_x in initial_x_list:
    plot_numeric_solutions(direction_field.subs(y, f), x, f, initial_conditions, init_x, (a, b), 100, axes8, legend=False, title=True, threshold=(a, b))
axes8.legend()

# %% [markdown]
# # $\frac{dy}{dx} = 10 + 3y - y^2$

# %%
diff_eq = sp.Eq(f.diff(x), 10 + 3*f - f**2)
diff_eq
# Out:
# Eq(Derivative(f(x), x), -f(x)**2 + 3*f(x) + 10)

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), -(2*exp(7*C1 - 7*x) + 5)/(exp(7*C1 - 7*x) - 1))

# %%
direction_field = diff_eq.rhs.subs(f, y)
direction_field
# Out:
# -y**2 + 3*y + 10

# %%
a, b = -5, 5
x_values = np.linspace(a, b, 500)
consts = [[(C1, i)] for i in range(-5, 6, 1)]
figure9, axes9 = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes9, threshold=(a, b))
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes9, title=False)
# Out:
# <lambdifygenerated-216>:2: RuntimeWarning: divide by zero encountered in divide
#   return -(2*exp(-7*x - 35) + 5)/(exp(-7*x - 35) - 1)
# <lambdifygenerated-226>:2: RuntimeWarning: divide by zero encountered in divide
#   return -(2*exp(35 - 7*x) + 5)/(exp(35 - 7*x) - 1)
