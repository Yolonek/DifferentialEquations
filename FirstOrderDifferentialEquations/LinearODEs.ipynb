# %% [markdown]
# # Linear differential equations
#
# A first order DE is linear, if:
#
# $$ a_1(x) \frac{dy}{dx} + a_0(x)y = g(x) $$

# %%
import sys
sys.path.append('..')

# %%
from CommonFunctions import *
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %%
x, y = sp.symbols('x y')
f = sp.Function('f')(x)

# %% [markdown]
# # $\frac{dx}{dy} - 3y = 0$

# %%
diff_eq = sp.Eq(f.diff(x) - 3*f, 0)
diff_eq.subs(f, y)
# Out:
# Eq(-3*y + Derivative(y, x), 0)

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), C1*exp(3*x))

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# 3*y

# %%
C1 = sp.Symbol('C1')
a, b = -5, 5
x_values = np.linspace(a, b, 500)
consts = [[(C1, i)] for i in range(-5, 6, 2)]
figure, axes = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes, threshold=(a, b), legend=False)
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes, title=False)

# %% [markdown]
# # $x \frac{dy}{dx} - 4y = x^6e^x$

# %%
diff_eq = sp.Eq(x * f.diff(x) - 4*f, x**6 * sp.exp(x))
diff_eq
# Out:
# Eq(x*Derivative(f(x), x) - 4*f(x), x**6*exp(x))

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), x**4*(C1 + x*exp(x) - exp(x)))

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# (x**6*exp(x) + 4*y)/x

# %%
a, b = -5, 5
x_values = np.linspace(a, b, 500)
consts = [[(C1, 0.4)], [(C1, 1)], [(C1, 5)], [(C1, -1)], [(C1, -2)]]
figure, axes = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes, threshold=(a, b), legend=True)
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes, title=False)

# %% [markdown]
# # $(x^2 - 9) \frac{dy}{dx} + xy = 0$

# %%
diff_eq = sp.Eq((x**2 - 9) * f.diff(x) + x*f, 0)
diff_eq
# Out:
# Eq(x*f(x) + (x**2 - 9)*Derivative(f(x), x), 0)

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), C1/sqrt(x**2 - 9))

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# -x*y/(x**2 - 9)

# %%
a, b = -5, 5
x_values = np.linspace(a, b, 500)
consts = [[(C1, i)] for i in range(-5, 6, 2)]
figure, axes = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes, threshold=(a, b), legend=False)
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes, title=False)

c, d = -2.99, 2.99
initial_x = 0
initial_conditions = np.arange(-4, 5, 1)
plot_numeric_solutions(direction_field.subs(y, f), x, f, initial_conditions, initial_x, (c, d), 100, axes, legend=False, title=False, threshold=(a, b))
# Out:
# <lambdifygenerated-14>:2: RuntimeWarning: invalid value encountered in sqrt
#   return -5/sqrt(x**2 - 9)
# <lambdifygenerated-15>:2: RuntimeWarning: invalid value encountered in sqrt
#   return -3/sqrt(x**2 - 9)
# <lambdifygenerated-16>:2: RuntimeWarning: invalid value encountered in sqrt
#   return -1/sqrt(x**2 - 9)
# <lambdifygenerated-17>:2: RuntimeWarning: invalid value encountered in sqrt
#   return 1/sqrt(x**2 - 9)
# <lambdifygenerated-18>:2: RuntimeWarning: invalid value encountered in sqrt
#   return 3/sqrt(x**2 - 9)
# <lambdifygenerated-19>:2: RuntimeWarning: invalid value encountered in sqrt
#   return 5/sqrt(x**2 - 9)

# %% [markdown]
# # $\frac{dy}{dx} + y = x$

# %%
diff_eq = sp.Eq(f.diff(x) + f, x)
diff_eq.subs(f, y)
# Out:
# Eq(y + Derivative(y, x), x)

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), C1*exp(-x) + x - 1)

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# x - y

# %%
a, b = -5, 5
x_values = np.linspace(a, b, 500)
consts = [[(C1, i)] for i in range(-5, 6, 2)]
consts.append([(C1, 0)])
figure, axes = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
plot_many_functions(solution, x, diff_eq, x_values, consts, axes, threshold=(a, b), legend=True)
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes, title=False)

# %% [markdown]
# # $\frac{dy}{dx} - 2xy = 2$

# %%
diff_eq = sp.Eq(f.diff(x) - 2*f*x, 2)
diff_eq
# Out:
# Eq(-2*x*f(x) + Derivative(f(x), x), 2)

# %%
solution = sp.dsolve(diff_eq, f)
solution
# Out:
# Eq(f(x), (C1 + sqrt(pi)*erf(x))*exp(x**2))

# %%
direction_field = sp.solve(diff_eq, f.diff(x))[0].subs(f, y)
direction_field
# Out:
# 2*x*y + 2

# %%
figure, axes = plt.subplots(1, 1, figsize=(8, 8), layout='constrained')
initial_conditions = np.arange(-4, 5, 1)
initial_x = 0
plot_direction_field(x, y, direction_field, (a, b, a, b, .3), axes, title=True)
plot_numeric_solutions(direction_field.subs(y, f), x, f, initial_conditions, initial_x, (a, b), 200, axes, legend=False, title=True, threshold=(a, b))
initial_conditions = np.array([-4, 4])
for init_x in [-4, -3, -2, 2, 3, 4]:
    plot_numeric_solutions(direction_field.subs(y, f), x, f, initial_conditions, init_x, (a, b), 200, axes, legend=False, title=False, threshold=(a, b))
title = axes.get_title()
title = f'Symbolic solution: \n${equation_in_latex(solution)}$\n' + title
axes.set_title(title)
# Out:
# Text(0.5, 1.0, 'Symbolic solution: \n$f{\\left(x \\right)} = \\left(C_{1} + \\sqrt{\\pi} \\operatorname{erf}{\\left(x \\right)}\\right) e^{x^{2}}$\nNumerical solution for equation:\n$\\frac{dy}{dx} = 2 x f{\\left(x \\right)} + 2$')
